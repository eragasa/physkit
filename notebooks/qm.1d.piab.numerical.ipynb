# %%
from physkit.qm.models.piab1d import ParticleInABox1D

Lx = 1.
x_min = 0
x_max = x_min + Lx
Nx = 100

solver = ParticleInABox1D(
    x_min=x_min,
    x_max=x_max,
    Nx = 100
)

energies, states = solver.solve(n_states=4)
states = solver.normalize_states(states)

class VisualizePiab1D():
    def __init__(self, ParticleInABox1D):
        self.piab1d: ParticleInABox1D
        
print(energies)
print(states.shape)
print(solver.x_active.shape)
