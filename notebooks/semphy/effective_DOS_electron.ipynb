# %% [markdown]
# # Effective Density of States for Holes
# by Eugene Joseph M. Ragasa

# %% [markdown]
# ## Analytical Solution

# %%
class ParabolicConductionBand():
  
    def g_c(self.)

    @staticmethod
    def analytical_DOS_eff(
        temperature, 
        effective_mass_electron=1, 
        hbar=1,
        k_B=1):
        T = temperature
        m_e = effective_mass_electron
        N_c = 2 * (m_e * k_B * T / (hbar**2))**(3/2)
        return N_c


class ValenceBand():
    

    def N_v(self, T):
        pass


    @staticmethod
    def analytical_DOS_eff(
        temperature,
        effective_mass_hole=1.,
        hbar=1,
        k_B=1
    )
      T=temperature
      m_h =effective_mass_hole
      N_h = 2 * (m_h * k_B * T / (hbar**2))**(3/2)
      return N_v
