# %%
import math

class Wavefunction1d():
    x: float
    t: float
    A: float
    k: float
    omega: float

    @staticmethod
    def get_angular_frequency(frequency: float):
        omega = 2 * math.pi * frequency
        return omega
    
    @staticmethod
    def get_wavenumber_1d(wavelength: float):
        k = 2 * math.pi / wavelength
        return k


    @staticmethod
    def wavefunction_1d(x: float,t: float,A: float, k: float, omega: float):
        """
        not done

        """
        return psi
# Out:
#   Cell In[1], line 2
#     def get_wavenumber_1d(lambda: float):
#                           ^
# SyntaxError: invalid syntax
