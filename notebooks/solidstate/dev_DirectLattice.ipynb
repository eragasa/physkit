# %%
import numpy as np
class Lattice1D():
    def __init__(self, a: float):
        self.a: float = a

# %%
import numpy as np


class Lattice2D():
    def __init__(
            self, 
            a1: np.ndarray, 
            a2: np.ndarray
    ):
        self.a1: np.ndarray = a1
        self.a2: np.ndarray = a2
    
    @staticmethod
    def from_A(A: np.ndarray):
        a1 = A[:,0]
        a2 = A[:,1]
        return Lattice2D(a1=a1, a2=a2)

# %%
class Lattice3D():
    def __init__(
            self,
            a1: np.ndarray,
            a2: np.ndarray,
            a3: np.ndarray
    ):
        self.a1: np.ndarray = a1
        self.a2: np.ndarray = a2
        self.a3: np.ndarray = a3
        self.A
# Out:
# The kernel failed to start as 'MappingProxyType' could not be imported from 'most likely due to a circular import'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
