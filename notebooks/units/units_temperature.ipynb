# %%
from physkit.units import Temperature

# %%
T_given_value = 1200
T_given_units = Temperature.Units.C
T_units = Temperature.Units.K
T_K = Temperature.convert(
  from_ = [T_given_value, T_given_units], 
  to = T_units
)
print(T_K)
# Out:
# 1473.15
