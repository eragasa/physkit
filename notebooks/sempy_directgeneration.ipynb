# %%
def excess_carrier_concentration_n(
    n_n0: float
):
  """

  n_n0 (float): electron density at thermal equilbrium
  
  """
    delta_n = n_n - n_n0

def excess_carrier_concentration_p():
    delta_p = p_n - p_n0
