# %%
import pandas as pd

data = [
    ["Al-Cu alloy", 22000, 66000],
    ["Al-Cu alloy", 33000, 47000],
    ["Ti-6% Al-4% V", 50000, 130000],
    ["Ti-6% Al-4% V", 90000, 125000],
    ["Ni-Cr steel", 45800, 238000],
    ["Ni-Cr steel", 80000, 206000],
    ["Al2O3", 1600, 30000],
    ["Si3N4", 4500, 80000],
    ["Transformation toughened ZrO2", 10000, 60000],
    ["Si3N4-SiC composite", 51000, 120000],
    ["Polymethyl methacrylate polymer", 900, 4000],
    ["Polycarbonate polymer", 3000, 8400],
]

df = pd.DataFrame(
    data,
    columns=[
        "material",
        "fracture_toughness_KIc_psi_sqrt_in",
        "yield_or_ultimate_strength_psi",
    ],
)

df
# Out:
#                            material  fracture_toughness_KIc_psi_sqrt_in  \
# 0                       Al-Cu alloy                               22000
# 1                       Al-Cu alloy                               33000
# 2                     Ti-6% Al-4% V                               50000
# 3                     Ti-6% Al-4% V                               90000
# 4                       Ni-Cr steel                               45800
# 5                       Ni-Cr steel                               80000
# 6                             Al2O3                                1600
# 7                             Si3N4                                4500
# 8     Transformation toughened ZrO2                               10000
# 9               Si3N4-SiC composite                               51000
# 10  Polymethyl methacrylate polymer                                 900
# 11            Polycarbonate polymer                                3000
#
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1)
ax.scatter(
  df["fracture_toughness_KIc_psi_sqrt_in"],
  df["yield_or_ultimate_strength_psi"]
)
ax.set_xlabel(r"$K_{Ic}$ ($\text{\psi}$)")
# Out:
# Text(0.5, 0, '$K_{Ic}$ ($\\text{\\psi}$)')
