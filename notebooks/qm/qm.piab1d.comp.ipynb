# %%
from physkit.qm.models.piab1d import ParticleInABox1D

L = 1
x_min = 0
x_max = x_min + L
model = ParticleInABox1D(
    x_min=0.,
    x_max=L,
    Nx=50)
# Out:
#   Cell In[1], line 1
#     from physkit.units.force    5
#                                 ^
# SyntaxError: invalid syntax
